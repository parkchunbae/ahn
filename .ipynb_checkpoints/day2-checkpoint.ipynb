# %%
# 데이터셋 준비, 데이터셋 확인(개요, 단항, 여러항), 여러가지 전처리(sex,slb+parch, embarkced, miss-master), 피쳐 설계, 기계학습 예측모델, 제출
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('./titanic/train.csv', index_col='PassengerId')
test = pd.read_csv('./titanic/test.csv', index_col='PassengerId')
train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
test.tail()
# Out:
#              Pclass                          Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 1305              3            Spector, Mr. Woolf    male   NaN      0      0
# 1306              1  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 1307              3  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 1308              3           Ware, Mr. Frederick    male   NaN      0      0
# 1309              3      Peter, Master. Michael J    male   NaN      1      1
#
#                          Ticket      Fare Cabin Embarked
# PassengerId
# 1305                  A.5. 3236    8.0500   NaN        S
# 1306                   PC 17758  108.9000  C105        C
# 1307         SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308                     359309    8.0500   NaN        S
# 1309                       2668   22.3583   NaN        C

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
train.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
train.sample(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 614                 0       3
# 618                 0       3
# 255                 0       3
# 210                 1       1
# 638                 0       2
#
#                                                         Name     Sex   Age  \
# PassengerId
# 614                                         Horgan, Mr. John    male   NaN
# 618          Lobb, Mrs. William Arthur (Cordelia K Stanlick)  female  26.0
# 255                 Rosblom, Mrs. Viktor (Helena Wilhelmina)  female  41.0
# 210                                         Blank, Mr. Henry    male  40.0
# 638                                      Collyer, Mr. Harvey    male  31.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# 614              0      0      370377   7.7500   NaN        Q
# 618              1      0   A/5. 3336  16.1000   NaN        S
# 255              0      2      370129  20.2125   NaN        S
# 210              0      0      112277  31.0000   A31        C
# 638              1      1  C.A. 31921  26.2500   NaN        S

# %%
sns.countplot(data=train, x='Pclass', hue='Survived')

# %%
sns.countplot(data=train, x='Sex', hue='Survived')

# %%
sns.lmplot(data=train, x='Age', y='Fare', hue='Survived', fit_reg=False)

# %%
train["Fare"]
# Out:
# PassengerId
# 1       7.2500
# 2      71.2833
# 3       7.9250
# 4      53.1000
# 5       8.0500
#         ...
# 887    13.0000
# 888    30.0000
# 889    23.4500
# 890    30.0000
# 891     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
train["Fare"].loc[1:10]
# Out:
# PassengerId
# 1      7.2500
# 2     71.2833
# 3      7.9250
# 4     53.1000
# 5      8.0500
# 6      8.4583
# 7     51.8625
# 8     21.0750
# 9     11.1333
# 10    30.0708
# Name: Fare, dtype: float64

# %%
high_fare =  train.loc[train['Fare'] > 50]

# %%
sns.lmplot(data=high_fare, x='Age', y='Fare', hue='Survived', fit_reg=False)

# %%
high_fare.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 28                  0       1
# 32                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 28                              Fortune, Mr. Charles Alexander    male  19.0
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
#
#              SibSp  Parch    Ticket      Fare        Cabin Embarked
# PassengerId
# 2                1      0  PC 17599   71.2833          C85        C
# 4                1      0    113803   53.1000         C123        S
# 7                0      0     17463   51.8625          E46        S
# 28               3      2     19950  263.0000  C23 C25 C27        S
# 32               1      0  PC 17569  146.5208          B78        C

# %%
train['fare50'] = train.loc[train['Fare'] > 50, 'Fare']

# %%
sns.countplot(data=train, x="Embarked", hue="Survived")

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked   fare50
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S      NaN
# 2                1      0          PC 17599  71.2833   C85        C  71.2833
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S      NaN
# 4                1      0            113803  53.1000  C123        S  53.1000
# 5                0      0            373450   8.0500   NaN        S      NaN

# %%
train = train.drop(columns=['fare50'])
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.loc[train['Sex'] == 'male', 'Sex_encode'] = 0
train.loc[train['Sex'] == 'female', 'Sex_encode'] = 1

test.loc[test['Sex'] == 'male', 'Sex_encode'] = 0
test.loc[test['Sex'] == 'female', 'Sex_encode'] = 1

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              Sex_encode  sib_parch  Embarked_S  Embarked_C  Embarked_Q
# PassengerId
# 1                   0.0          1        True       False       False
# 2                   1.0          1       False        True       False
# 3                   1.0          0        True       False       False
# 4                   1.0          1        True       False       False
# 5                   0.0          0        True       False       False

# %%
(train['SibSp'] + train['Parch']).tail(10)
# Out:
# PassengerId
# 882    0
# 883    0
# 884    0
# 885    0
# 886    5
# 887    0
# 888    0
# 889    3
# 890    0
# 891    0
# dtype: int64

# %%
(train['SibSp']).tail(10)
# Out:
# PassengerId
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    0
# 888    0
# 889    1
# 890    0
# 891    0
# Name: SibSp, dtype: int64

# %%
train['sib_parch'] = (train['SibSp'] + train['Parch'])
test['sib_parch'] = (test['SibSp'] + test['Parch'])
train.tail(10)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 882                 0       3                        Markun, Mr. Johann
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 884                 0       2             Banfield, Mr. Frederick James
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 882            male  33.0      0      0            349257   7.8958   NaN
# 883          female  22.0      0      0              7552  10.5167   NaN
# 884            male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN
# 885            male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN
# 886          female  39.0      0      5            382652  29.1250   NaN
# 887            male  27.0      0      0            211536  13.0000   NaN
# 888          female  19.0      0      0            112053  30.0000   B42
# 889          female   NaN      1      2        W./C. 6607  23.4500   NaN
# 890            male  26.0      0      0            111369  30.0000  C148
# 891            male  32.0      0      0            370376   7.7500   NaN
#
#             Embarked  Sex_encode  sib_parch  Embarked_S  Embarked_C  \
# PassengerId
# 882                S         0.0          0        True       False
# 883                S         1.0          0        True       False
# 884                S         0.0          0        True       False
# 885                S         0.0          0        True       False
# 886                Q         1.0          5       False       False
# 887                S         0.0          0        True       False
# 888                S         1.0          0        True       False
# 889                S         1.0          3        True       False
# 890                C         0.0          0       False        True
# 891                Q         0.0          0       False       False
#
#              Embarked_Q
# PassengerId
# 882               False
# 883               False
# 884               False
# 885               False
# 886                True
# 887               False
# 888               False
# 889               False
# 890               False
# 891                True

# %%
train.loc[train['Embarked'] == 'S', 'Embarked_S'] = True
train.loc[train['Embarked'] != 'S', 'Embarked_S'] = False
train.loc[train['Embarked'] == 'C', 'Embarked_C'] = True
train.loc[train['Embarked'] != 'C', 'Embarked_C'] = False
train.loc[train['Embarked'] == 'Q', 'Embarked_Q'] = True
train.loc[train['Embarked'] != 'Q', 'Embarked_Q'] = False

test.loc[test['Embarked'] == 'S', 'Embarked_S'] = True
test.loc[test['Embarked'] != 'S', 'Embarked_S'] = False
test.loc[test['Embarked'] == 'C', 'Embarked_C'] = True
test.loc[test['Embarked'] != 'C', 'Embarked_C'] = False
test.loc[test['Embarked'] == 'Q', 'Embarked_Q'] = True
test.loc[test['Embarked'] != 'Q', 'Embarked_Q'] = False
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              Sex_encode  sib_parch  Embarked_S  Embarked_C  Embarked_Q
# PassengerId
# 1                   0.0          1        True       False       False
# 2                   1.0          1       False        True       False
# 3                   1.0          0        True       False       False
# 4                   1.0          1        True       False       False
# 5                   0.0          0        True       False       False

# %%
train.sample(10)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 299                 1       1                     Saalfeld, Mr. Adolphe
# 399                 0       2                          Pain, Dr. Alfred
# 44                  1       2  Laroche, Miss. Simonne Marie Anne Andree
# 552                 0       2               Sharp, Mr. Percival James R
# 368                 1       3            Moussa, Mrs. (Mantoura Boulos)
# 343                 0       2                Collander, Mr. Erik Gustaf
# 605                 1       1           Homer, Mr. Harry ("Mr E Haven")
# 305                 0       3         Williams, Mr. Howard Hugh "Harry"
# 704                 0       3                     Gallagher, Mr. Martin
# 233                 0       2                 Sjostedt, Mr. Ernst Adolf
#
#                 Sex   Age  SibSp  Parch         Ticket     Fare Cabin  \
# PassengerId
# 299            male   NaN      0      0          19988  30.5000  C106
# 399            male  23.0      0      0         244278  10.5000   NaN
# 44           female   3.0      1      2  SC/Paris 2123  41.5792   NaN
# 552            male  27.0      0      0         244358  26.0000   NaN
# 368          female   NaN      0      0           2626   7.2292   NaN
# 343            male  28.0      0      0         248740  13.0000   NaN
# 605            male  35.0      0      0         111426  26.5500   NaN
# 305            male   NaN      0      0       A/5 2466   8.0500   NaN
# 704            male  25.0      0      0          36864   7.7417   NaN
# 233            male  59.0      0      0         237442  13.5000   NaN
#
#             Embarked  Sex_encode  sib_parch  Embarked_S  Embarked_C  \
# PassengerId
# 299                S         0.0          0        True       False
# 399                S         0.0          0        True       False
# 44                 C         1.0          3       False        True
# 552                S         0.0          0        True       False
# 368                C         1.0          0       False        True
# 343                S         0.0          0        True       False
# 605                C         0.0          0       False        True
# 305                S         0.0          0        True       False
# 704                Q         0.0          0       False       False
# 233                S         0.0          0        True       False
#
#              Embarked_Q
# PassengerId
# 299               False
# 399               False
# 44                False
# 552               False
# 368               False
# 343               False
# 605               False
# 305               False
# 704                True
# 233               False

# %%
train['Name'].head(5)
# Out:
# PassengerId
# 1                              Braund, Mr. Owen Harris
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# train['Name'].str.slice(start=???, stop=???)
# start[3] = train["Name"].str.index(", ") = [1,2,3,4,56,6,7,7]데이터프레임중 해당하는 데이터값
# stop = train["Name"].str.index(". ") 데이터프레임중 해당하는 데이터값
# train['Name'] -> for- only one row! -> for countValue=>[1,2,3,4,56,6,7,7] countValue
# countplot - > 처리 마무리
# 아래는 예제코드
# startNums = train["Name"].str.index(", ")
# train['Name'].str.slice(start=(train["Name"].str.index(", "))
# Out:
# PassengerId
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
#        ..
# 887   NaN
# 888   NaN
# 889   NaN
# 890   NaN
# 891   NaN
# Name: Name, Length: 891, dtype: float64

# %%
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              Sex_encode  sib_parch  Embarked_S  Embarked_C  Embarked_Q
# PassengerId
# 1                   0.0          1        True       False       False
# 2                   1.0          1       False        True       False
# 3                   1.0          0        True       False       False
# 4                   1.0          1        True       False       False
# 5                   0.0          0        True       False       False

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        Sex_encode   sib_parch
# count  891.000000  891.000000
# mean     0.352413    0.904602
# std      0.477990    1.613459
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    1.000000
# max      1.000000   10.000000

# %%
train.loc[train['Age'].isna()] = 30
test.loc[test['Age'].isna()] = 30
train.loc[train['Fare'].isna()] = 32
test.loc[test['Fare'].isna()] = 32

train.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         529
# Embarked        2
# Sex_encode      0
# sib_parch       0
# Embarked_S      0
# Embarked_C      0
# Embarked_Q      0
# dtype: int64

# %%
# X
feature_names = ['Pclass','Age',  'Fare',  'Sex_encode', 'sib_parch', 'Embarked_S',
       'Embarked_C', 'Embarked_Q']
# Y
label_name = 'Survived'

X_train = train[feature_names]
X_test = test[feature_names]
Y_train = train[label_name]

# %%
Y_train.isna().sum()
Y_train.head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
# tree.DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=82, max_depth=5)
model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=82, splitter='best')

# %%
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=82, splitter='best')

# %%
# graphviz 모듈을 가져옵니다.
import graphviz

# scikit-learn(줄여서 sklearn)의 tree 모듈에서 Decision Tree를 시각화 할 수 있는 export_graphviz를 가져옵니다.
from sklearn.tree import export_graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-149-dde89d1e0c9f> in <module>
#       1 # graphviz 모듈을 가져옵니다.
# ----> 2 import graphviz
#       3
#       4 # scikit-learn(줄여서 sklearn)의 tree 모듈에서 Decision Tree를 시각화 할 수 있는 export_graphviz를 가져옵니다.
#       5 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'graphviz'
